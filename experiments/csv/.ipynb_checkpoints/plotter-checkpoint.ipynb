# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./fast_model_weight_performance.csv', sep=',')

# %%
df
# Out:
#      confidence  layer  dropout output
# 0      0.862415      1        0    bee
# 1      0.660513      1        5    bee
# 2      0.460248      1       10    bee
# 3      0.171593      1       15    bee
# 4      0.057175      1       20    bee
# 5      0.115913      1       25    bee
# 6      0.001091      1       30    bee
# 7      0.005045      1       35    bee
# 8      0.000423      1       40    bee
# 9      0.000389      1       45    bee
# 10     0.002743      1       50    bee
# 11     0.000139      1       55    bee
# 12     0.003267      1       60    bee
# 13     0.000904      1       65    bee
# 14     0.000147      1       70    bee
# 15     0.000100      1       75    bee
# 16     0.000377      1       80    bee
# 17     0.000197      1       85    bee
# 18     0.000275      1       90    bee
# 19     0.000304      1       95    bee
# 20     0.000965      1      100    bee
# 21     0.862415      2        0    bee
# 22     0.611657      2        5    bee
# 23     0.853199      2       10    bee
# 24     0.541984      2       15    bee
# 25     0.711276      2       20    bee
# 26     0.595596      2       25    bee
# 27     0.276618      2       30    bee
# 28     0.343536      2       35    bee
# 29     0.163619      2       40    bee
# ..          ...    ...      ...    ...
# 138    0.609055      7       60    bee
# 139    0.637019      7       65    bee
# 140    0.523615      7       70    bee
# 141    0.418648      7       75    bee
# 142    0.379763      7       80    bee
# 143    0.131669      7       85    bee
# 144    0.044514      7       90    bee
# 145    0.006809      7       95    bee
# 146    0.000965      7      100    bee
# 147    0.862415      8        0    bee
# 148    0.927893      8        5    bee
# 149    0.721219      8       10    bee
# 150    0.800397      8       15    bee
# 151    0.783233      8       20    bee
# 152    0.746439      8       25    bee
# 153    0.137671      8       30    bee
# 154    0.745913      8       35    bee
# 155    0.625655      8       40    bee
# 156    0.240661      8       45    bee
# 157    0.381021      8       50    bee
# 158    0.714740      8       55    bee
# 159    0.279131      8       60    bee
# 160    0.146654      8       65    bee
# 161    0.371318      8       70    bee
# 162    0.272115      8       75    bee
# 163    0.064248      8       80    bee
# 164    0.024683      8       85    bee
# 165    0.011868      8       90    bee
# 166    0.003987      8       95    bee
# 167    0.001000      8      100    bee
#
# [168 rows x 4 columns]

# %%
NUM_LAYERS = 8
DATA_PER_LAYER = 21
dropout_column = df.dropout.iloc[0:DATA_PER_LAYER]
new_df = pd.DataFrame(dropout_column)
print(new_df)
all_confidences = []
for layer in range(1, NUM_LAYERS + 1):
    df_layer = df.iloc[(layer - 1) * DATA_PER_LAYER : layer * DATA_PER_LAYER, :]
    df_layer_filtered = df_layer[df_layer.output.str.contains("bee")]
    df_layer_to_plot = df_layer_filtered[['confidence', 'dropout']].copy()
    df_layer_to_plot = df_layer_to_plot.rename(index=str, columns={"confidence": ("Layer " + str(layer))})
    df_layer_to_plot = df_layer_to_plot.drop(columns='dropout').reset_index()
    print(df_layer_to_plot)
    all_confidences.append(df_layer_to_plot.iloc[:,1])

confidence_df = pd.concat(all_confidences, axis=1, sort=False, ignore_index=False)
confidence_df['dropout'] = dropout_column
confidence_df

# plotting
fig = confidence_df.plot(x='dropout', y=['Layer 1'], title=("Fast Model Layers"))
fig.set_xlabel('DropOut (%)')
fig.set_ylabel('Confidence');
figure = fig.get_figure()
figure.savefig(fname=("./plots/fast_model.png"))
# Out:
#     dropout
# 0         0
# 1         5
# 2        10
# 3        15
# 4        20
# 5        25
# 6        30
# 7        35
# 8        40
# 9        45
# 10       50
# 11       55
# 12       60
# 13       65
# 14       70
# 15       75
# 16       80
# 17       85
# 18       90
# 19       95
# 20      100
#    index   Layer 1
# 0      0  0.862415
# 1      1  0.660513
# 2      2  0.460248
# 3      3  0.171593
# 4      4  0.057175
# 5      5  0.115913
# 6      6  0.001091
# 7      7  0.005045
# 8      8  0.000423
# 9      9  0.000389
# 10    10  0.002743
# 11    11  0.000139
# 12    12  0.003267
# 13    13  0.000904
# 14    14  0.000147
# 15    15  0.000100
# 16    16  0.000377
# 17    17  0.000197
# 18    18  0.000275
# 19    19  0.000304
# 20    20  0.000965
#    index       Layer 2
# 0     21  8.624150e-01
# 1     22  6.116570e-01
# 2     23  8.531990e-01
# 3     24  5.419840e-01
# 4     25  7.112760e-01
# 5     26  5.955960e-01
# 6     27  2.766180e-01
# 7     28  3.435360e-01
# 8     29  1.636190e-01
# 9     30  4.628110e-01
# 10    31  1.499550e-01
# 11    32  9.506500e-02
# 12    33  1.367250e-01
# 13    34  5.012500e-02
# 14    35  9.162270e-03
# 15    36  4.552340e-03
# 16    37  2.538300e-03
# 17    38  9.500510e-04
# 18    39  9.652100e-04
# 19    40  9.652100e-04
# 20    41  5.468980e-07
#    index       Layer 3
# 0     42  8.624150e-01
# 1     43  8.800350e-01
# 2     44  8.561740e-01
# 3     45  9.501700e-01
# 4     46  8.547450e-01
# 5     47  4.048280e-01
# 6     48  8.271500e-01
# 7     49  6.295570e-01
# 8     50  8.775670e-01
# 9     51  4.498770e-01
# 10    52  8.239160e-01
# 11    53  7.168400e-01
# 12    54  8.728520e-07
# 13    55  2.731160e-05
# 14    56  8.396950e-07
# 15    57  6.005470e-07
# 16    58  5.468980e-07
# 17    59  5.468980e-07
# 18    60  5.468980e-07
# 19    61  5.468980e-07
# 20    62  9.652100e-04
#    index       Layer 4
# 0     63  8.624150e-01
# 1     64  8.300610e-01
# 2     65  7.336690e-01
# 3     66  8.273610e-01
